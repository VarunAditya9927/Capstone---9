# %%
import pandas as pd
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA
from sklearn.model_selection import GridSearchCV
from sklearn.cluster import KMeans
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import roc_curve, auc,accuracy_score,recall_score
import matplotlib.pyplot as plt
import numpy as np

# %%
df1 = pd.read_csv("Telco-Customer-Churn.csv")
df1.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
# 1          No          No              No        One year               No
# 2          No          No              No  Month-to-month              Yes
# 3         Yes          No              No        One year               No
# 4          No          No              No  Month-to-month              Yes
#
#                PaymentMethod MonthlyCharges  TotalCharges Churn
# 0           Electronic check          29.85         29.85    No
# 1               Mailed check          56.95        1889.5    No
# 2               Mailed check          53.85        108.15   Yes
# 3  Bank transfer (automatic)          42.30       1840.75    No
# 4           Electronic check          70.70        151.65   Yes
#
# [5 rows x 21 columns]

# %%
df2 = pd.read_csv('Customer_Churn.csv')
df2.head()
# Out:
#    Unnamed: 0 Customer ID  Gender  Age Married  Number of Dependents  \
# 0           0  0002-ORFBO  Female   37     Yes                     0
# 1           1  0003-MKNFE    Male   46      No                     0
# 2           2  0004-TLHLJ    Male   50      No                     0
# 3           3  0011-IGKFF    Male   78     Yes                     0
# 4           4  0013-EXCHZ  Female   75     Yes                     0
#
#            City  Zip Code   Latitude   Longitude  ...  Paperless Billing  \
# 0  Frazier Park     93225  34.827662 -118.999073  ...                Yes
# 1      Glendale     91206  34.162515 -118.203869  ...                 No
# 2    Costa Mesa     92627  33.645672 -117.922613  ...                Yes
# 3      Martinez     94553  38.014457 -122.115432  ...                Yes
# 4     Camarillo     93010  34.227846 -119.079903  ...                Yes
#
#     Payment Method Monthly Charge Total Charges  Total Refunds  \
# 0      Credit Card           65.6        593.30           0.00
# 1      Credit Card           -4.0        542.40          38.33
# 2  Bank Withdrawal           73.9        280.85           0.00
# 3  Bank Withdrawal           98.0       1237.85           0.00
# 4      Credit Card           83.9        267.40           0.00
#
#   Total Extra Data Charges Total Long Distance Charges Customer Status  \
# 0                        0                      381.51          Stayed
# 1                       10                       96.21          Stayed
# 2                        0                      134.60         Churned
# 3                        0                      361.66         Churned
# 4                        0                       22.14         Churned
#
#     Churn Category                   Churn Reason
# 0              NaN                            NaN
# 1              NaN                            NaN
# 2       Competitor  Competitor had better devices
# 3  Dissatisfaction        Product dissatisfaction
# 4  Dissatisfaction            Network reliability
#
# [5 rows x 38 columns]

# %% [markdown]
# ## Merging Two Dataframes based on Customer_ID

# %%
df2.isnull().sum()
# Out:
# Unnamed: 0                              0
# Customer ID                             0
# Gender                                  0
# Age                                     0
# Married                                 0
# Number of Dependents                    0
# City                                    0
# Zip Code                                0
# Latitude                                0
# Longitude                               0
# Number of Referrals                     0
# Tenure in Months                        0
# Offer                                3877
# Phone Service                           0
# Avg Monthly Long Distance Charges     682
# Multiple Lines                        682
# Internet Service                        0
# Internet Type                        1526
# Avg Monthly GB Download              1526
# Online Security                      1526
# Online Backup                        1526
# Device Protection Plan               1526
# Premium Tech Support                 1526
# Streaming TV                         1526
# Streaming Movies                     1526
# Streaming Music                      1526
# Unlimited Data                       1526
# Contract                                0
# Paperless Billing                       0
# Payment Method                          0
# Monthly Charge                          0
# Total Charges                           0
# Total Refunds                           0
# Total Extra Data Charges                0
# Total Long Distance Charges             0
# Customer Status                         0
# Churn Category                       5174
# Churn Reason                         5174
# dtype: int64

# %%
column_mapping = {
    'customerID': 'Customer ID',
    'gender': 'Gender',
    'Partner': 'Married',
    'Dependents': 'Number of Dependents',
    'tenure': 'Tenure in Months',
    'PhoneService': 'Phone Service',
    'MultipleLines': 'Multiple Lines',
    'InternetService': 'Internet Service',
    'OnlineSecurity': 'Online Security',
    'OnlineBackup': 'Online Backup',
    'DeviceProtection': 'Device Protection Plan',
    'TechSupport': 'Premium Tech Support',
    'StreamingTV': 'Streaming TV',
    'StreamingMovies': 'Streaming Movies',
    'Contract': 'Contract',
    'PaperlessBilling': 'Paperless Billing',
    'PaymentMethod': 'Payment Method',
    'MonthlyCharges': 'Monthly Charge',
    'TotalCharges': 'Total Charges',
    'Churn': 'Churn'
}

# %%
df1.rename(columns=column_mapping, inplace=True)

# %%
combined_df = pd.merge(df1, df2, how='inner', on='Customer ID')

# %%
combined_df.columns
# Out:
# Index(['Customer ID', 'Gender_x', 'SeniorCitizen', 'Married_x',
#        'Number of Dependents_x', 'Tenure in Months_x', 'Phone Service_x',
#        'Multiple Lines_x', 'Internet Service_x', 'Online Security_x',
#        'Online Backup_x', 'Device Protection Plan_x', 'Premium Tech Support_x',
#        'Streaming TV_x', 'Streaming Movies_x', 'Contract_x',
#        'Paperless Billing_x', 'Payment Method_x', 'Monthly Charge_x',
#        'Total Charges_x', 'Churn', 'Unnamed: 0', 'Gender_y', 'Age',
#        'Married_y', 'Number of Dependents_y', 'City', 'Zip Code', 'Latitude',
#        'Longitude', 'Number of Referrals', 'Tenure in Months_y', 'Offer',
#        'Phone Service_y', 'Avg Monthly Long Distance Charges',
#        'Multiple Lines_y', 'Internet Service_y', 'Internet Type',
#        'Avg Monthly GB Download', 'Online Security_y', 'Online Backup_y',
#        'Device Protection Plan_y', 'Premium Tech Support_y', 'Streaming TV_y',
#        'Streaming Movies_y', 'Streaming Music', 'Unlimited Data', 'Contract_y',
#        'Paperless Billing_y', 'Payment Method_y', 'Monthly Charge_y',
#        'Total Charges_y', 'Total Refunds', 'Total Extra Data Charges',
#        'Total Long Distance Charges', 'Customer Status', 'Churn Category',
#        'Churn Reason'],
#       dtype='object')

# %%
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 58 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Customer ID                        7043 non-null   object
#  1   Gender_x                           7043 non-null   object
#  2   SeniorCitizen                      7043 non-null   int64
#  3   Married_x                          7043 non-null   object
#  4   Number of Dependents_x             7043 non-null   object
#  5   Tenure in Months_x                 7043 non-null   int64
#  6   Phone Service_x                    7043 non-null   object
#  7   Multiple Lines_x                   7043 non-null   object
#  8   Internet Service_x                 7043 non-null   object
#  9   Online Security_x                  7043 non-null   object
#  10  Online Backup_x                    7043 non-null   object
#  11  Device Protection Plan_x           7043 non-null   object
#  12  Premium Tech Support_x             7043 non-null   object
#  13  Streaming TV_x                     7043 non-null   object
#  14  Streaming Movies_x                 7043 non-null   object
#  15  Contract_x                         7043 non-null   object
#  16  Paperless Billing_x                7043 non-null   object
#  17  Payment Method_x                   7043 non-null   object
#  18  Monthly Charge_x                   7043 non-null   float64
#  19  Total Charges_x                    7043 non-null   object
#  20  Churn                              7043 non-null   object
#  21  Unnamed: 0                         7043 non-null   int64
#  22  Gender_y                           7043 non-null   object
#  23  Age                                7043 non-null   int64
#  24  Married_y                          7043 non-null   object
#  25  Number of Dependents_y             7043 non-null   int64
#  26  City                               7043 non-null   object
#  27  Zip Code                           7043 non-null   int64
#  28  Latitude                           7043 non-null   float64
#  29  Longitude                          7043 non-null   float64
#  30  Number of Referrals                7043 non-null   int64
#  31  Tenure in Months_y                 7043 non-null   int64
#  32  Offer                              3166 non-null   object
#  33  Phone Service_y                    7043 non-null   object
#  34  Avg Monthly Long Distance Charges  6361 non-null   float64
#  35  Multiple Lines_y                   6361 non-null   object
#  36  Internet Service_y                 7043 non-null   object
#  37  Internet Type                      5517 non-null   object
#  38  Avg Monthly GB Download            5517 non-null   float64
#  39  Online Security_y                  5517 non-null   object
#  40  Online Backup_y                    5517 non-null   object
#  41  Device Protection Plan_y           5517 non-null   object
#  42  Premium Tech Support_y             5517 non-null   object
#  43  Streaming TV_y                     5517 non-null   object
#  44  Streaming Movies_y                 5517 non-null   object
#  45  Streaming Music                    5517 non-null   object
#  46  Unlimited Data                     5517 non-null   object
#  47  Contract_y                         7043 non-null   object
#  48  Paperless Billing_y                7043 non-null   object
#  49  Payment Method_y                   7043 non-null   object
#  50  Monthly Charge_y                   7043 non-null   float64
#  51  Total Charges_y                    7043 non-null   float64
#  52  Total Refunds                      7043 non-null   float64
#  53  Total Extra Data Charges           7043 non-null   int64
#  54  Total Long Distance Charges        7043 non-null   float64
#  55  Customer Status                    7043 non-null   object
#  56  Churn Category                     1869 non-null   object
#  57  Churn Reason                       1869 non-null   object
# dtypes: float64(9), int64(9), object(40)
# memory usage: 3.1+ MB

# %%
combined_df.drop(combined_df.columns[3:20], axis=1, inplace=True)

# %%
combined_df.drop(combined_df.columns[1:2],axis=1,inplace=True)
combined_df.drop('Unnamed: 0',axis=1,inplace=True)

# %%
combined_df.columns = combined_df.columns.str.replace('_y', '')

# %%
len(combined_df.columns)
# Out:
# 39

# %%
## Storing Churn Reasons for future Use

reasons_df= combined_df.loc[combined_df['Churn'] == 'Yes', ['Customer ID', 'Churn Reason']]
combined_df_copy = combined_df.copy()

# %%
combined_df['Churn'].value_counts()
# Out:
# Churn
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %%
# The 1869 value indicates that customers who were not churned has reason as Null values.
combined_df['Churn Reason'].notnull().sum()
# Out:
# np.int64(1869)

# %%
combined_df.describe()
# Out:
#        SeniorCitizen          Age  Number of Dependents      Zip Code  \
# count    7043.000000  7043.000000           7043.000000   7043.000000
# mean        0.162147    46.509726              0.468692  93486.070567
# std         0.368612    16.750352              0.962802   1856.767505
# min         0.000000    19.000000              0.000000  90001.000000
# 25%         0.000000    32.000000              0.000000  92101.000000
# 50%         0.000000    46.000000              0.000000  93518.000000
# 75%         0.000000    60.000000              0.000000  95329.000000
# max         1.000000    80.000000              9.000000  96150.000000
#
#           Latitude    Longitude  Number of Referrals  Tenure in Months  \
# count  7043.000000  7043.000000          7043.000000       7043.000000
# mean     36.197455  -119.756684             1.951867         32.386767
# std       2.468929     2.154425             3.001199         24.542061
# min      32.555828  -124.301372             0.000000          1.000000
# 25%      33.990646  -121.788090             0.000000          9.000000
# 50%      36.205465  -119.595293             0.000000         29.000000
# 75%      38.161321  -117.969795             3.000000         55.000000
# max      41.962127  -114.192901            11.000000         72.000000
#
#        Avg Monthly Long Distance Charges  Avg Monthly GB Download  \
# count                        6361.000000              5517.000000
# mean                           25.420517                26.189958
# std                            14.200374                19.586585
# min                             1.010000                 2.000000
# 25%                            13.050000                13.000000
# 50%                            25.690000                21.000000
# 75%                            37.680000                30.000000
# max                            49.990000                85.000000
#
#        Monthly Charge  Total Charges  Total Refunds  Total Extra Data Charges  \
# count     7043.000000    7043.000000    7043.000000               7043.000000
# mean        63.596131    2280.381264       1.962182                  6.860713
# std         31.204743    2266.220462       7.902614                 25.104978
# min        -10.000000      18.800000       0.000000                  0.000000
# 25%         30.400000     400.150000       0.000000                  0.000000
# 50%         70.050000    1394.550000       0.000000                  0.000000
# 75%         89.750000    3786.600000       0.000000                  0.000000
# max        118.750000    8684.800000      49.790000                150.000000
#
#        Total Long Distance Charges
# count                  7043.000000
# mean                    749.099262
# std                     846.660055
# min                       0.000000
# 25%                      70.545000
# 50%                     401.440000
# 75%                    1191.100000
# max                    3564.720000

# %% [markdown]
# ## Data Pre-Processing

# %%
combined_df.isnull().sum()
# Out:
# Customer ID                             0
# SeniorCitizen                           0
# Churn                                   0
# Gender                                  0
# Age                                     0
# Married                                 0
# Number of Dependents                    0
# City                                    0
# Zip Code                                0
# Latitude                                0
# Longitude                               0
# Number of Referrals                     0
# Tenure in Months                        0
# Offer                                3877
# Phone Service                           0
# Avg Monthly Long Distance Charges     682
# Multiple Lines                        682
# Internet Service                        0
# Internet Type                        1526
# Avg Monthly GB Download              1526
# Online Security                      1526
# Online Backup                        1526
# Device Protection Plan               1526
# Premium Tech Support                 1526
# Streaming TV                         1526
# Streaming Movies                     1526
# Streaming Music                      1526
# Unlimited Data                       1526
# Contract                                0
# Paperless Billing                       0
# Payment Method                          0
# Monthly Charge                          0
# Total Charges                           0
# Total Refunds                           0
# Total Extra Data Charges                0
# Total Long Distance Charges             0
# Customer Status                         0
# Churn Category                       5174
# Churn Reason                         5174
# dtype: int64

# %% [markdown]
# - Since, the number of missing values are way too high, we need to fill them with appropriate imputation techniques

# %%
# Filling Null Values
# If feature is object, we fill it with mode else mean
for i in combined_df.columns:
    if i != 'Churn Reason':  # Skip imputation for 'Churn Reason' column
        if combined_df[i].dtype == 'object':
            if combined_df[i].isnull().sum() != 0:
                combined_df[i].fillna(combined_df[i].mode()[0], inplace=True)
        else:
            if combined_df[i].isnull().sum() != 0:
                combined_df[i].fillna(combined_df[i].mean(), inplace=True)
# Out:
# <ipython-input-19-aa32d70f0922>:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   combined_df[i].fillna(combined_df[i].mode()[0], inplace=True)
# <ipython-input-19-aa32d70f0922>:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   combined_df[i].fillna(combined_df[i].mean(), inplace=True)

# %%
combined_df.isnull().sum()
# Out:
# Customer ID                             0
# SeniorCitizen                           0
# Churn                                   0
# Gender                                  0
# Age                                     0
# Married                                 0
# Number of Dependents                    0
# City                                    0
# Zip Code                                0
# Latitude                                0
# Longitude                               0
# Number of Referrals                     0
# Tenure in Months                        0
# Offer                                   0
# Phone Service                           0
# Avg Monthly Long Distance Charges       0
# Multiple Lines                          0
# Internet Service                        0
# Internet Type                           0
# Avg Monthly GB Download                 0
# Online Security                         0
# Online Backup                           0
# Device Protection Plan                  0
# Premium Tech Support                    0
# Streaming TV                            0
# Streaming Movies                        0
# Streaming Music                         0
# Unlimited Data                          0
# Contract                                0
# Paperless Billing                       0
# Payment Method                          0
# Monthly Charge                          0
# Total Charges                           0
# Total Refunds                           0
# Total Extra Data Charges                0
# Total Long Distance Charges             0
# Customer Status                         0
# Churn Category                          0
# Churn Reason                         5174
# dtype: int64

# %%
combined_df.head()
# Out:
#   Customer ID  SeniorCitizen Churn  Gender  Age Married  Number of Dependents  \
# 0  7590-VHVEG              0    No  Female   36     Yes                     0
# 1  5575-GNVDE              0    No    Male   46      No                     0
# 2  3668-QPYBK              0   Yes    Male   37      No                     0
# 3  7795-CFOCW              0    No    Male   53      No                     0
# 4  9237-HQITU              0   Yes  Female   19      No                     2
#
#           City  Zip Code   Latitude  ...  Paperless Billing   Payment Method  \
# 0  Los Angeles     90001  33.973616  ...                Yes  Bank Withdrawal
# 1  Los Angeles     90002  33.949255  ...                 No     Mailed Check
# 2  Los Angeles     90003  33.964131  ...                Yes      Credit Card
# 3  Los Angeles     90004  34.076259  ...                 No  Bank Withdrawal
# 4  Los Angeles     90005  34.059281  ...                Yes  Bank Withdrawal
#
#    Monthly Charge Total Charges Total Refunds  Total Extra Data Charges  \
# 0           29.85         29.85           0.0                         0
# 1           56.95       1889.50           0.0                         0
# 2           53.85        108.15           0.0                         0
# 3           42.30       1840.75           0.0                         0
# 4           70.70        151.65           0.0                         0
#
#   Total Long Distance Charges Customer Status Churn Category  \
# 0                        0.00          Joined     Competitor
# 1                      581.06          Stayed     Competitor
# 2                       20.94         Churned     Competitor
# 3                        0.00          Stayed     Competitor
# 4                       18.24         Churned          Other
#
#                    Churn Reason
# 0                           NaN
# 1                           NaN
# 2  Competitor made better offer
# 3                           NaN
# 4                         Moved
#
# [5 rows x 39 columns]

# %% [markdown]
# ## Converting Tenure from months to years

# %%
combined_df['Tenure In Years']=round(combined_df['Tenure in Months']/12,2)
combined_df.drop("Tenure in Months",axis=1,inplace=True)

# %%
len(combined_df.columns)
# Out:
# 39

# %% [markdown]
# ## Calculating Customer Life Time Value

# %%
combined_df.columns
# Out:
# Index(['Customer ID', 'SeniorCitizen', 'Churn', 'Gender', 'Age', 'Married',
#        'Number of Dependents', 'City', 'Zip Code', 'Latitude', 'Longitude',
#        'Number of Referrals', 'Offer', 'Phone Service',
#        'Avg Monthly Long Distance Charges', 'Multiple Lines',
#        'Internet Service', 'Internet Type', 'Avg Monthly GB Download',
#        'Online Security', 'Online Backup', 'Device Protection Plan',
#        'Premium Tech Support', 'Streaming TV', 'Streaming Movies',
#        'Streaming Music', 'Unlimited Data', 'Contract', 'Paperless Billing',
#        'Payment Method', 'Monthly Charge', 'Total Charges', 'Total Refunds',
#        'Total Extra Data Charges', 'Total Long Distance Charges',
#        'Customer Status', 'Churn Category', 'Churn Reason', 'Tenure In Years'],
#       dtype='object')

# %%
combined_df["Transaction"]=combined_df["Total Charges"]/combined_df["Monthly Charge"]
combined_df['Transaction']=round(combined_df['Transaction'],0)

# %%
# Calculating Total Revenue for Each Customer
combined_df['Total Revenue']= combined_df['Total Charges'] + combined_df['Total Extra Data Charges'] + combined_df['Total Long Distance Charges']-combined_df['Total Refunds']

# %%
combined_df.head()
# Out:
#   Customer ID  SeniorCitizen Churn  Gender  Age Married  Number of Dependents  \
# 0  7590-VHVEG              0    No  Female   36     Yes                     0
# 1  5575-GNVDE              0    No    Male   46      No                     0
# 2  3668-QPYBK              0   Yes    Male   37      No                     0
# 3  7795-CFOCW              0    No    Male   53      No                     0
# 4  9237-HQITU              0   Yes  Female   19      No                     2
#
#           City  Zip Code   Latitude  ...  Total Charges  Total Refunds  \
# 0  Los Angeles     90001  33.973616  ...          29.85            0.0
# 1  Los Angeles     90002  33.949255  ...        1889.50            0.0
# 2  Los Angeles     90003  33.964131  ...         108.15            0.0
# 3  Los Angeles     90004  34.076259  ...        1840.75            0.0
# 4  Los Angeles     90005  34.059281  ...         151.65            0.0
#
#   Total Extra Data Charges Total Long Distance Charges  Customer Status  \
# 0                        0                        0.00           Joined
# 1                        0                      581.06           Stayed
# 2                        0                       20.94          Churned
# 3                        0                        0.00           Stayed
# 4                        0                       18.24          Churned
#
#   Churn Category                  Churn Reason Tenure In Years  Transaction  \
# 0     Competitor                           NaN            0.08          1.0
# 1     Competitor                           NaN            2.83         33.0
# 2     Competitor  Competitor made better offer            0.17          2.0
# 3     Competitor                           NaN            3.75         44.0
# 4          Other                         Moved            0.17          2.0
#
#   Total Revenue
# 0         29.85
# 1       2470.56
# 2        129.09
# 3       1840.75
# 4        169.89
#
# [5 rows x 41 columns]

# %%
def cltv_c(dataframe):
    cltv_c = dataframe.groupby('Customer ID').agg({
          'Total Revenue': lambda x: x.sum(),
          'Transaction': lambda x: x.sum(),
          'Total Charges': lambda x: x.sum(),
          'Tenure In Years': 'mean'
      })
    cltv_c.columns = ['total_revenue', 'transaction', 'total_charges', 'average_tenure']
    cltv_c['avg_order_value'] = cltv_c['total_charges'] / cltv_c['transaction']
    cltv_c["purchase_frequency"] = cltv_c['transaction'] / cltv_c.shape[0]
    cltv_c['customer_value'] = (cltv_c['avg_order_value'] * cltv_c["purchase_frequency"])
    cltv_c['cltv'] = cltv_c['customer_value'] * cltv_c['average_tenure']

    return cltv_c

# %%
cltv_df=cltv_c(combined_df)

# %%
combined_df = pd.merge(combined_df, cltv_df['cltv'], on='Customer ID', how='left')

# %%
combined_df.head()
# Out:
#   Customer ID  SeniorCitizen Churn  Gender  Age Married  Number of Dependents  \
# 0  7590-VHVEG              0    No  Female   36     Yes                     0
# 1  5575-GNVDE              0    No    Male   46      No                     0
# 2  3668-QPYBK              0   Yes    Male   37      No                     0
# 3  7795-CFOCW              0    No    Male   53      No                     0
# 4  9237-HQITU              0   Yes  Female   19      No                     2
#
#           City  Zip Code   Latitude  ...  Total Refunds  \
# 0  Los Angeles     90001  33.973616  ...            0.0
# 1  Los Angeles     90002  33.949255  ...            0.0
# 2  Los Angeles     90003  33.964131  ...            0.0
# 3  Los Angeles     90004  34.076259  ...            0.0
# 4  Los Angeles     90005  34.059281  ...            0.0
#
#    Total Extra Data Charges Total Long Distance Charges Customer Status  \
# 0                         0                        0.00          Joined
# 1                         0                      581.06          Stayed
# 2                         0                       20.94         Churned
# 3                         0                        0.00          Stayed
# 4                         0                       18.24         Churned
#
#    Churn Category                  Churn Reason Tenure In Years Transaction  \
# 0      Competitor                           NaN            0.08         1.0
# 1      Competitor                           NaN            2.83        33.0
# 2      Competitor  Competitor made better offer            0.17         2.0
# 3      Competitor                           NaN            3.75        44.0
# 4           Other                         Moved            0.17         2.0
#
#    Total Revenue      cltv
# 0          29.85  0.000339
# 1        2470.56  0.759234
# 2         129.09  0.002610
# 3        1840.75  0.980095
# 4         169.89  0.003660
#
# [5 rows x 42 columns]

# %% [markdown]
# ## Labelling Customers based on CLTV

# %%
clust_df=combined_df[['Customer ID','Offer','Premium Tech Support','Contract','cltv']]

# %% [markdown]
# ## Reasons for only considering these columns to label customer value
# - No of Referrals has more 0 values, so if you calculate kmeans cluster it is giving more weightage to number of referrals and labelling low cltv values customers as high.

# %%
clust_df.head()
# Out:
#   Customer ID    Offer Premium Tech Support        Contract      cltv
# 0  7590-VHVEG  Offer E                   No  Month-to-Month  0.000339
# 1  5575-GNVDE  Offer B                   No        One Year  0.759234
# 2  3668-QPYBK  Offer B                   No  Month-to-Month  0.002610
# 3  7795-CFOCW  Offer B                  Yes        One Year  0.980095
# 4  9237-HQITU  Offer B                   No  Month-to-Month  0.003660

# %%
LE=LabelEncoder()
columns_to_encode = ['Offer','Contract','Premium Tech Support']
for column in columns_to_encode:
    clust_df[column] = LE.fit_transform(clust_df[column])
# Out:
# <ipython-input-34-01953ef2bb65>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clust_df[column] = LE.fit_transform(clust_df[column])
# <ipython-input-34-01953ef2bb65>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clust_df[column] = LE.fit_transform(clust_df[column])
# <ipython-input-34-01953ef2bb65>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clust_df[column] = LE.fit_transform(clust_df[column])

# %%
clust_df.head()
# Out:
#   Customer ID  Offer  Premium Tech Support  Contract      cltv
# 0  7590-VHVEG      4                     0         0  0.000339
# 1  5575-GNVDE      1                     0         1  0.759234
# 2  3668-QPYBK      1                     0         0  0.002610
# 3  7795-CFOCW      1                     1         1  0.980095
# 4  9237-HQITU      1                     0         0  0.003660

# %%
kmeans = KMeans(n_clusters=3, random_state=42)
kmeans.fit(clust_df.iloc[:,1:])
clust_df['Cluster'] = kmeans.fit_predict(clust_df.iloc[:,1:])
cluster_labels = {
    0: 'High',
    1: 'Medium',
    2: 'Low'
}
clust_df['Cluster'] = clust_df['Cluster'].map(cluster_labels)
# Out:
# <ipython-input-36-ebe231bbcb06>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clust_df['Cluster'] = kmeans.fit_predict(clust_df.iloc[:,1:])
# <ipython-input-36-ebe231bbcb06>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clust_df['Cluster'] = clust_df['Cluster'].map(cluster_labels)

# %%
clust_df.head()
# Out:
#   Customer ID  Offer  Premium Tech Support  Contract      cltv Cluster
# 0  7590-VHVEG      4                     0         0  0.000339     Low
# 1  5575-GNVDE      1                     0         1  0.759234    High
# 2  3668-QPYBK      1                     0         0  0.002610     Low
# 3  7795-CFOCW      1                     1         1  0.980095    High
# 4  9237-HQITU      1                     0         0  0.003660     Low

# %%
combined_df['Cluster'] = clust_df['Cluster']

# %%
clust_df['Cluster'].value_counts()
# Out:
# Cluster
# Low       3174
# High      2533
# Medium    1336
# Name: count, dtype: int64

# %%
combined_df.head()
# Out:
#   Customer ID  SeniorCitizen Churn  Gender  Age Married  Number of Dependents  \
# 0  7590-VHVEG              0    No  Female   36     Yes                     0
# 1  5575-GNVDE              0    No    Male   46      No                     0
# 2  3668-QPYBK              0   Yes    Male   37      No                     0
# 3  7795-CFOCW              0    No    Male   53      No                     0
# 4  9237-HQITU              0   Yes  Female   19      No                     2
#
#           City  Zip Code   Latitude  ...  Total Extra Data Charges  \
# 0  Los Angeles     90001  33.973616  ...                         0
# 1  Los Angeles     90002  33.949255  ...                         0
# 2  Los Angeles     90003  33.964131  ...                         0
# 3  Los Angeles     90004  34.076259  ...                         0
# 4  Los Angeles     90005  34.059281  ...                         0
#
#    Total Long Distance Charges Customer Status Churn Category  \
# 0                         0.00          Joined     Competitor
# 1                       581.06          Stayed     Competitor
# 2                        20.94         Churned     Competitor
# 3                         0.00          Stayed     Competitor
# 4                        18.24         Churned          Other
#
#                    Churn Reason Tenure In Years Transaction Total Revenue  \
# 0                           NaN            0.08         1.0         29.85
# 1                           NaN            2.83        33.0       2470.56
# 2  Competitor made better offer            0.17         2.0        129.09
# 3                           NaN            3.75        44.0       1840.75
# 4                         Moved            0.17         2.0        169.89
#
#        cltv Cluster
# 0  0.000339     Low
# 1  0.759234    High
# 2  0.002610     Low
# 3  0.980095    High
# 4  0.003660     Low
#
# [5 rows x 43 columns]

# %%
# Encoding Cluster Names
cluster_mapping = {'Low': 0, 'Medium': 1, 'High': 2}
combined_df['Cluster'] = combined_df['Cluster'].map(cluster_mapping)

# %%
combined_df['Cluster']
# Out:
# 0       0
# 1       2
# 2       0
# 3       2
# 4       0
#        ..
# 7038    0
# 7039    1
# 7040    0
# 7041    0
# 7042    1
# Name: Cluster, Length: 7043, dtype: int64

# %% [markdown]
# ## Feature Reduction Using PCA

# %%
columns_to_encode = [col for col in combined_df.columns[1:-1] if col != 'Churn Reason' and combined_df[col].dtype == 'object']
LE = LabelEncoder()
for i in columns_to_encode:
    combined_df[i] = LE.fit_transform(combined_df[i])

# %%
reduced_df=combined_df.drop(['Customer ID','Zip Code','Latitude','Longitude','Paperless Billing','Payment Method','Churn Category','Churn Reason','Transaction'],axis=1)
combined_df.drop(['Customer ID','Zip Code','Latitude','Longitude','Paperless Billing','Payment Method','Churn Category','Transaction'],axis=1,inplace=True)

# %%
combined_df[['Streaming TV', 'Streaming Movies', 'Streaming Music']].corr()
# Out:
#                   Streaming TV  Streaming Movies  Streaming Music
# Streaming TV          1.000000          0.533094         0.455387
# Streaming Movies      0.533094          1.000000         0.848528
# Streaming Music       0.455387          0.848528         1.000000

# %%
columns_for_pca = ['Streaming TV', 'Streaming Movies', 'Streaming Music']

pca = PCA(n_components=2)
scaler=StandardScaler()
pca_components = pca.fit_transform(scaler.fit_transform(reduced_df[columns_for_pca]))

explained_variance_ratio = pca.explained_variance_ratio_
print("Explained Variance Ratio:", explained_variance_ratio)

reduced_df['Streaming Services-1'] = pca_components[:, 0]
reduced_df['Streaming Services-2'] = pca_components[:, 1]

combined_df['Streaming Services-1'] = pca_components[:, 0]
combined_df['Streaming Services-2'] = pca_components[:, 1]

reduced_df.drop(columns=columns_for_pca, inplace=True)
combined_df.drop(columns=columns_for_pca, inplace=True)
# Out:
# Explained Variance Ratio: [0.74741967 0.20386504]

# %%
reduced_df.head()
# Out:
#    SeniorCitizen  Churn  Gender  Age  Married  Number of Dependents  City  \
# 0              0      0       0   36        1                     0   554
# 1              0      0       1   46        0                     0   554
# 2              0      1       1   37        0                     0   554
# 3              0      0       1   53        0                     0   554
# 4              0      1       0   19        0                     2   554
#
#    Number of Referrals  Offer  Phone Service  ...  Total Refunds  \
# 0                    0      4              0  ...            0.0
# 1                    0      1              1  ...            0.0
# 2                    0      1              1  ...            0.0
# 3                    0      1              0  ...            0.0
# 4                    0      1              1  ...            0.0
#
#    Total Extra Data Charges  Total Long Distance Charges  Customer Status  \
# 0                         0                         0.00                1
# 1                         0                       581.06                2
# 2                         0                        20.94                0
# 3                         0                         0.00                2
# 4                         0                        18.24                0
#
#    Tenure In Years  Total Revenue      cltv  Cluster  Streaming Services-1  \
# 0             0.08          29.85  0.000339        0             -1.333973
# 1             2.83        2470.56  0.759234        2             -1.333973
# 2             0.17         129.09  0.002610        0             -1.333973
# 3             3.75        1840.75  0.980095        2             -1.333973
# 4             0.17         169.89  0.003660        0             -1.333973
#
#    Streaming Services-2
# 0             -0.157216
# 1             -0.157216
# 2             -0.157216
# 3             -0.157216
# 4             -0.157216
#
# [5 rows x 33 columns]

# %%
combined_df[['Monthly Charge', 'Total Charges', 'Total Refunds','Total Extra Data Charges','Total Long Distance Charges','Avg Monthly Long Distance Charges']].corr()
# Out:
#                                    Monthly Charge  Total Charges  \
# Monthly Charge                           1.000000       0.622810
# Total Charges                            0.622810       1.000000
# Total Refunds                            0.023963       0.039558
# Total Extra Data Charges                 0.121238       0.121859
# Total Long Distance Charges              0.235685       0.610185
# Avg Monthly Long Distance Charges        0.018455       0.016546
#
#                                    Total Refunds  Total Extra Data Charges  \
# Monthly Charge                          0.023963                  0.121238
# Total Charges                           0.039558                  0.121859
# Total Refunds                           1.000000                  0.016755
# Total Extra Data Charges                0.016755                  1.000000
# Total Long Distance Charges             0.028113                  0.058871
# Avg Monthly Long Distance Charges      -0.024869                  0.019822
#
#                                    Total Long Distance Charges  \
# Monthly Charge                                        0.235685
# Total Charges                                         0.610185
# Total Refunds                                         0.028113
# Total Extra Data Charges                              0.058871
# Total Long Distance Charges                           1.000000
# Avg Monthly Long Distance Charges                     0.525222
#
#                                    Avg Monthly Long Distance Charges
# Monthly Charge                                              0.018455
# Total Charges                                               0.016546
# Total Refunds                                              -0.024869
# Total Extra Data Charges                                    0.019822
# Total Long Distance Charges                                 0.525222
# Avg Monthly Long Distance Charges                           1.000000

# %%
columns_for_pca = ['Monthly Charge', 'Total Charges', 'Total Refunds','Total Extra Data Charges','Total Long Distance Charges','Avg Monthly Long Distance Charges']

pca = PCA(n_components=4)
pca_components = pca.fit_transform(scaler.fit_transform(reduced_df[columns_for_pca]))

explained_variance_ratio = pca.explained_variance_ratio_
print("Explained Variance Ratio:", explained_variance_ratio)

reduced_df['Charges-1'] = pca_components[:, 0]
reduced_df['Charges-2'] = pca_components[:, 1]
reduced_df['Charges-3'] = pca_components[:, 2]
reduced_df['Charges-4'] = pca_components[:, 3]

combined_df['Charges-1'] = pca_components[:, 0]
combined_df['Charges-2'] = pca_components[:, 1]
combined_df['Charges-3'] = pca_components[:, 2]
combined_df['Charges-4'] = pca_components[:, 3]

reduced_df.drop(columns=columns_for_pca, inplace=True)
combined_df.drop(columns=columns_for_pca, inplace=True)
# Out:
# Explained Variance Ratio: [0.35304704 0.20746549 0.16577886 0.16020383]

# %%
reduced_df.head()
# Out:
#    SeniorCitizen  Churn  Gender  Age  Married  Number of Dependents  City  \
# 0              0      0       0   36        1                     0   554
# 1              0      0       1   46        0                     0   554
# 2              0      1       1   37        0                     0   554
# 3              0      0       1   53        0                     0   554
# 4              0      1       0   19        0                     2   554
#
#    Number of Referrals  Offer  Phone Service  ...  Tenure In Years  \
# 0                    0      4              0  ...             0.08
# 1                    0      1              1  ...             2.83
# 2                    0      1              1  ...             0.17
# 3                    0      1              0  ...             3.75
# 4                    0      1              1  ...             0.17
#
#    Total Revenue      cltv  Cluster  Streaming Services-1  \
# 0          29.85  0.000339        0             -1.333973
# 1        2470.56  0.759234        2             -1.333973
# 2         129.09  0.002610        0             -1.333973
# 3        1840.75  0.980095        2             -1.333973
# 4         169.89  0.003660        0             -1.333973
#
#    Streaming Services-2  Charges-1  Charges-2  Charges-3  Charges-4
# 0             -0.157216  -1.651737   0.524479  -0.109299   0.098462
# 1             -0.157216  -0.542043  -0.285755  -0.260714  -0.284047
# 2             -0.157216  -1.569044  -0.617957  -0.270518  -0.188623
# 3             -0.157216  -0.989208   0.123773  -0.201134  -0.091736
# 4             -0.157216  -1.333120  -0.933175  -0.340048  -0.283804
#
# [5 rows x 31 columns]

# %%
reduced_df.columns
# Out:
# Index(['SeniorCitizen', 'Churn', 'Gender', 'Age', 'Married',
#        'Number of Dependents', 'City', 'Number of Referrals', 'Offer',
#        'Phone Service', 'Multiple Lines', 'Internet Service', 'Internet Type',
#        'Avg Monthly GB Download', 'Online Security', 'Online Backup',
#        'Device Protection Plan', 'Premium Tech Support', 'Unlimited Data',
#        'Contract', 'Customer Status', 'Tenure In Years', 'Total Revenue',
#        'cltv', 'Cluster', 'Streaming Services-1', 'Streaming Services-2',
#        'Charges-1', 'Charges-2', 'Charges-3', 'Charges-4'],
#       dtype='object')

# %%
combined_df.columns
# Out:
# Index(['SeniorCitizen', 'Churn', 'Gender', 'Age', 'Married',
#        'Number of Dependents', 'City', 'Number of Referrals', 'Offer',
#        'Phone Service', 'Multiple Lines', 'Internet Service', 'Internet Type',
#        'Avg Monthly GB Download', 'Online Security', 'Online Backup',
#        'Device Protection Plan', 'Premium Tech Support', 'Unlimited Data',
#        'Contract', 'Customer Status', 'Churn Reason', 'Tenure In Years',
#        'Total Revenue', 'cltv', 'Cluster', 'Streaming Services-1',
#        'Streaming Services-2', 'Charges-1', 'Charges-2', 'Charges-3',
#        'Charges-4'],
#       dtype='object')

# %%
combined_df[['Number of Dependents', 'Online Backup', 'Online Security', 'Avg Monthly GB Download','Churn']].corr()
# Out:
#                          Number of Dependents  Online Backup  Online Security  \
# Number of Dependents                 1.000000       0.001721         0.041977
# Online Backup                        0.001721       1.000000         0.283832
# Online Security                      0.041977       0.283832         1.000000
# Avg Monthly GB Download              0.248410       0.032511         0.068969
# Churn                               -0.218780      -0.082255        -0.171226
#
#                          Avg Monthly GB Download     Churn
# Number of Dependents                    0.248410 -0.218780
# Online Backup                           0.032511 -0.082255
# Online Security                         0.068969 -0.171226
# Avg Monthly GB Download                 1.000000 -0.084292
# Churn                                  -0.084292  1.000000

# %%
model_df = reduced_df.drop(['SeniorCitizen','Phone Service', 'Multiple Lines', 'Internet Service', 'Internet Type',
       'Avg Monthly GB Download', 'Online Backup','Customer Status'],axis=1)
combined_df.drop(['SeniorCitizen','Phone Service', 'Multiple Lines', 'Internet Service', 'Internet Type',
       'Avg Monthly GB Download', 'Online Backup','Customer Status'],axis=1,inplace=True)

# %%
model_df.columns
# Out:
# Index(['Churn', 'Gender', 'Age', 'Married', 'Number of Dependents', 'City',
#        'Number of Referrals', 'Offer', 'Online Security',
#        'Device Protection Plan', 'Premium Tech Support', 'Unlimited Data',
#        'Contract', 'Tenure In Years', 'Total Revenue', 'cltv', 'Cluster',
#        'Streaming Services-1', 'Streaming Services-2', 'Charges-1',
#        'Charges-2', 'Charges-3', 'Charges-4'],
#       dtype='object')

# %% [markdown]
# ## Splitting into Train and Test Data

# %%
x=model_df.drop('Churn',axis=1)
y=model_df['Churn']

# %%
# Training and testing for churn prediction
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
# Training data for churn reason prediction

# Get the indices of records in x_test
indices_to_exclude = x_test.index

# Create x_train_reason by excluding records present in x_test
x_train_reason = combined_df[(combined_df['Churn'] == 1) & (~combined_df.index.isin(indices_to_exclude))]

# Create y_train_reason corresponding to x_train_reason
y_train_reason = x_train_reason['Churn Reason']

# Drop the 'Churn Reason' column from x_train_reason
x_train_reason.drop(['Churn Reason','Churn'], axis=1, inplace=True)
# Out:
# <ipython-input-58-3fef2cf05c5a>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x_train_reason.drop(['Churn Reason','Churn'], axis=1, inplace=True)

# %%
x_train_reason
# Out:
#       Gender  Age  Married  Number of Dependents  City  Number of Referrals  \
# 2          1   37        0                     0   554                    0
# 4          0   19        0                     2   554                    0
# 5          0   31        0                     2   554                    0
# 13         1   38        0                     1   554                    0
# 18         0   21        1                     0   854                    6
# ...      ...  ...      ...                   ...   ...                  ...
# 7018       1   64        1                     2   695                    1
# 7021       1   44        0                     0   723                    0
# 7026       0   40        0                     0   905                    0
# 7032       1   79        0                     0   306                    0
# 7041       1   75        1                     0   316                    0
#
#       Offer  Online Security  Device Protection Plan  Premium Tech Support  \
# 2         1                1                       0                     0
# 4         1                0                       0                     0
# 5         1                0                       1                     0
# 13        1                0                       1                     0
# 18        1                0                       1                     1
# ...     ...              ...                     ...                   ...
# 7018      1                0                       0                     0
# 7021      3                0                       0                     1
# 7026      1                0                       0                     0
# 7032      1                0                       0                     0
# 7041      1                0                       0                     0
#
#       ...  Tenure In Years  Total Revenue      cltv  Cluster  \
# 2     ...             0.17         129.09  0.002610        0
# 4     ...             0.17         169.89  0.003660        0
# 5     ...             0.67         917.70  0.078054        0
# 13    ...             4.08        7208.47  2.917522        2
# 18    ...             0.83         622.45  0.062265        0
# ...   ...              ...            ...       ...      ...
# 7018  ...             0.08         108.33  0.000802        0
# 7021  ...             1.00         843.00  0.103337        0
# 7026  ...             0.75         780.63  0.042952        0
# 7032  ...             0.08          84.10  0.000860        0
# 7041  ...             0.33         369.04  0.014366        0
#
#       Streaming Services-1  Streaming Services-2  Charges-1  Charges-2  \
# 2                -1.333973             -0.157216  -1.569044  -0.617957
# 4                -1.333973             -0.157216  -1.333120  -0.933175
# 5                 2.227598              0.186057  -0.603732  -1.224686
# 13                2.227598              0.186057   2.625339   0.820637
# 18               -1.333973             -0.157216  -1.412004  -0.714972
# ...                    ...                   ...        ...        ...
# 7018             -1.333973             -0.157216  -0.741027   0.625236
# 7021             -0.325106              1.622951  -1.272123  -0.784960
# 7026             -1.333973             -0.157216  -0.737632   1.328836
# 7032             -1.333973             -0.157216  -1.299465  -1.040135
# 7041             -1.333973             -0.157216  -1.068568  -1.088837
#
#       Charges-3  Charges-4
# 2     -0.270518  -0.188623
# 4     -0.340048  -0.283804
# 5     -0.443543  -0.433743
# 13    -0.281941  -0.489975
# 18    -0.286838  -0.241256
# ...         ...        ...
# 7018  -0.197841   0.048530
# 7021  -0.306552  -0.275683
# 7026  -0.067987   0.177239
# 7032  -0.360949  -0.309537
# 7041  -0.352247   0.470398
#
# [1496 rows x 22 columns]

# %% [markdown]
# ## Model Building

# %%
accuracy_models={}
recall_models={}

# %% [markdown]
# ## Decision Tree

# %%
DT = DecisionTreeClassifier()
DT.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
DT_y_pred = DT.predict(x_test)

# %%
print("The Accuracy of the Decision Tree Model is: {}%".format(round(accuracy_score(y_test,DT_y_pred)*100,2)))
accuracy_models['Decision Tree']=round(accuracy_score(y_test,DT_y_pred)*100,2)
# Out:
# The Accuracy of the Decision Tree Model is: 78.28%

# %%
print("The Recall of the Decision Tree Model is: {}%".format(round(recall_score(y_test,DT_y_pred)*100,2)))
recall_models['Decision Tree']=round(recall_score(y_test,DT_y_pred)*100,2)
# Out:
# The Recall of the Decision Tree Model is: 61.39%

# %%
# Confusion Matrix

from sklearn.metrics import confusion_matrix
print("Confusion Matrix of Decision Tree Model:")
cf_indi_rand= pd.DataFrame(confusion_matrix(y_test,DT_y_pred),columns=['Predicted_0','Predicted_1'])
cf_indi_rand.index=['Actual_0','Actual_1']
cf_indi_rand
# Out:
# Confusion Matrix of Decision Tree Model:
#           Predicted_0  Predicted_1
# Actual_0          874          162
# Actual_1          144          229

# %% [markdown]
# ## Logistic Regression

# %%
LR = LogisticRegression()
LR.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
LR_ypred = LR.predict(x_test)

# %%
print("The Accuracy of the Logistic Regression Model is: {}%".format(round(accuracy_score(y_test,LR_ypred)*100,2)))
accuracy_models['Logistic Regression']=round(accuracy_score(y_test,LR_ypred)*100,2)
# Out:
# The Accuracy of the Logistic Regression Model is: 84.1%

# %%
print("The Recall of the Logistic Regression Model is: {}%".format(round(recall_score(y_test,LR_ypred)*100,2)))
recall_models['Logistic Regression']=round(recall_score(y_test,LR_ypred)*100,2)
# Out:
# The Recall of the Logistic Regression Model is: 66.22%

# %%
# Confusion Matrix

from sklearn.metrics import confusion_matrix,recall_score
print("Confusion Matrix of Logistic Regression Model:")
cf_indi_rand= pd.DataFrame(confusion_matrix(y_test,LR_ypred),columns=['Predicted_0','Predicted_1'])
cf_indi_rand.index=['Actual_0','Actual_1']
cf_indi_rand
# Out:
# Confusion Matrix of Logistic Regression Model:
#           Predicted_0  Predicted_1
# Actual_0          938           98
# Actual_1          126          247

# %% [markdown]
# ## Individual Random Forest Model

# %%
RF = RandomForestClassifier()
RF.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
indi_rf_ypred = RF.predict(x_test)

# %%
print("The Accuracy of the Random Forest Model: {} %".format(round(accuracy_score(y_test,indi_rf_ypred)*100,2)))
accuracy_models['Random Forest']=round(accuracy_score(y_test,indi_rf_ypred)*100,2)
# Out:
# The Accuracy of the Random Forest Model: 84.6 %

# %%
print("The Recall of the Random Forest Model: {} %".format(round(recall_score(y_test,indi_rf_ypred)*100,2)))
recall_models['Random Forest']=round(recall_score(y_test,indi_rf_ypred)*100,2)
# Out:
# The Recall of the Random Forest Model: 63.54 %

# %%
# Confusion Matrix

from sklearn.metrics import confusion_matrix
print("Confusion Matrix of Random Forest Model:")
cf_indi_rand= pd.DataFrame(confusion_matrix(y_test,indi_rf_ypred),columns=['Predicted_0','Predicted_1'])
cf_indi_rand.index=['Actual_0','Actual_1']
cf_indi_rand
# Out:
# Confusion Matrix of Random Forest Model:
#           Predicted_0  Predicted_1
# Actual_0          955           81
# Actual_1          136          237

# %% [markdown]
# ### Hyperparameter Tuning

# %%
param = {
    'n_estimators': [10,20,50,100],
    'max_features': ['sqrt', 'log2'],
    'max_depth': [2,4,6,8],
    'criterion': ['gini', 'entropy']
}

RF1 = RandomForestClassifier(random_state=10)

grid = GridSearchCV(estimator=RF1,
                    param_grid=param,
                    scoring="accuracy",
                    verbose=1, cv=5)

grid.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 64 candidates, totalling 320 fits
# GridSearchCV(cv=5, estimator=RandomForestClassifier(random_state=10),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [2, 4, 6, 8],
#                          'max_features': ['sqrt', 'log2'],
#                          'n_estimators': [10, 20, 50, 100]},
#              scoring='accuracy', verbose=1)

# %%
grid.best_params_
# Out:
# {'criterion': 'gini',
#  'max_depth': 8,
#  'max_features': 'sqrt',
#  'n_estimators': 100}

# %%
rf1 = grid.best_estimator_

# %%
tuned_y_pred = rf1.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
print("The Accuracy of the Tuned Random Forest Model is: {}%".format(round(accuracy_score(y_test,tuned_y_pred)*100,2)))
accuracy_models['Tuned Random Forest']=round(accuracy_score(y_test,tuned_y_pred)*100,2)
# Out:
# The Accuracy of the Tuned Random Forest Model is: 84.67%

# %%
from sklearn.metrics import accuracy_score
print("The recall of the Tuned Random Forest Model is: {}%".format(round(recall_score(y_test,tuned_y_pred)*100,2)))
recall_models['Tuned Random Forest']=round(recall_score(y_test,tuned_y_pred)*100,2)
# Out:
# The recall of the Tuned Random Forest Model is: 60.86%

# %%
# Confusion Matrix

from sklearn.metrics import confusion_matrix
print("Confusion Matrix of Tuned Random Forest Model:")
cf_tuned_rand= pd.DataFrame(confusion_matrix(y_test,tuned_y_pred),columns=['Predicted_0','Predicted_1'])
cf_tuned_rand.index=['Actual_0','Actual_1']
cf_tuned_rand
# Out:
# Confusion Matrix of Tuned Random Forest Model:
#           Predicted_0  Predicted_1
# Actual_0          966           70
# Actual_1          146          227

# %%
accuracies_df = pd.DataFrame.from_dict(accuracy_models, orient='index', columns=['Accuracy'])
accuracies_df['Recall']=recall_models
accuracies_df.index.name = 'Model Name'
accuracies_df.head()
# Out:
#                      Accuracy  Recall
# Model Name
# Decision Tree           78.28   61.39
# Logistic Regression     84.10   66.22
# Random Forest           84.60   63.54
# Tuned Random Forest     84.67   60.86

# %% [markdown]
# ## Finding Target Customers

# %%
# adding best model predictions to test set.
x_test['Churn']=LR_ypred

# %%
len(x_test)
# Out:
# 1409

# %%
# High Valued
print("Total Number of High-valued customers that are going to churn: ",len(x_test[(x_test['Cluster'] == 2) & (x_test['Churn'] == 1)][['Cluster','Churn']]))
x_test[(x_test['Cluster'] == 2) & (x_test['Churn'] == 1)][['Cluster','Churn']].head()
# Out:
# Total Number of High-valued customers that are going to churn:  21
#       Cluster  Churn
# 4645        2      1
# 2873        2      1
# 3172        2      1
# 3910        2      1
# 6131        2      1

# %%
# Medium Valued

print("Total Number of Medium-valued customers that are going to churn: ",len(x_test[(x_test['Cluster'] == 1) & (x_test['Churn'] == 1)][['Cluster','Churn']]))
x_test[(x_test['Cluster'] == 1) & (x_test['Churn'] == 1)][['Cluster','Churn']].head()
# Out:
# Total Number of Medium-valued customers that are going to churn:  17
#       Cluster  Churn
# 1263        1      1
# 4395        1      1
# 2206        1      1
# 6035        1      1
# 2609        1      1

# %%
# Low Valued

len(x_test[(x_test['Cluster'] == 0) & (x_test['Churn'] == 1)][['Cluster','Churn']])
# Out:
# 307

# %%
# High Valued customers retained

len(x_test[(x_test['Cluster'] == 2) & (x_test['Churn'] == 0)][['Cluster','Churn']])
# Out:
# 473

# %%
original_customer_ids = combined_df_copy.iloc[x_test[(x_test['Cluster'] == 2) & (x_test['Churn'] == 1)][['Cluster','Churn']]
.index]['Customer ID']

# %%
print("Customer ID's of High-Valued Customers that are going to Churn: ")
original_customer_ids
# Out:
# Customer ID's of High-Valued Customers that are going to Churn:
# 4645    5219-YIPTK
# 2873    0148-DCDOS
# 3172    8393-DLHGA
# 3910    8938-UMKPI
# 6131    1095-JUDTC
# 6773    3990-QYKBE
# 3458    0311-UNPFF
# 6606    6518-LGAOV
# 625     3003-CMDUU
# 6156    0118-JPNOY
# 3262    5498-TXHLF
# 1926    6651-AZVTJ
# 4307    6899-PPEEA
# 2948    2845-AFFTX
# 6993    6583-QGCSI
# 4314    4597-NUCQV
# 3841    4039-HEUNW
# 3950    5655-JSMZM
# 3666    3194-ORPIK
# 4558    8063-GBATB
# 1883    8840-DQLGN
# Name: Customer ID, dtype: object

# %% [markdown]
# ## Predict Churn Reasons for the High-Valued Customers

# %%
# target_cust_df is the customer id's of customer who are high valued and churn is yes
target_cust_df=combined_df_copy[combined_df_copy['Customer ID'].isin(original_customer_ids)]

# %%
target_cust_df=target_cust_df.merge(reasons_df,on='Customer ID')

# %%
target_cust_df.head()
# Out:
#   Customer ID  SeniorCitizen Churn  Gender  Age Married  Number of Dependents  \
# 0  8840-DQLGN              1   Yes  Female   65     Yes                     0
# 1  6651-AZVTJ              0   Yes    Male   27     Yes                     0
# 2  0148-DCDOS              0   Yes    Male   41      No                     0
# 3  2845-AFFTX              1   Yes    Male   78     Yes                     0
# 4  8393-DLHGA              0   Yes    Male   55      No                     0
#
#        City  Zip Code   Latitude  ...   Payment Method  Monthly Charge  \
# 0   Burbank     91502  34.177267  ...  Bank Withdrawal           100.5
# 1    Pomona     91768  34.067932  ...  Bank Withdrawal            99.8
# 2   Planada     95365  37.329725  ...  Bank Withdrawal            94.7
# 3  Westport     95488  39.724433  ...  Bank Withdrawal            99.8
# 4   Palermo     95968  39.435756  ...  Bank Withdrawal            95.9
#
#    Total Charges Total Refunds Total Extra Data Charges  \
# 0        3653.35          0.00                        0
# 1        4872.45          0.00                      130
# 2        2362.10          0.00                        0
# 3        4259.30          8.88                        0
# 4        2448.75          0.00                        0
#
#    Total Long Distance Charges Customer Status   Churn Category  \
# 0                       559.30         Churned         Attitude
# 1                      2300.06         Churned         Attitude
# 2                       872.00         Churned       Competitor
# 3                       924.96         Churned  Dissatisfaction
# 4                       131.75         Churned       Competitor
#
#                   Churn Reason_x                 Churn Reason_y
# 0     Attitude of support person     Attitude of support person
# 1     Attitude of support person     Attitude of support person
# 2  Competitor had better devices  Competitor had better devices
# 3        Product dissatisfaction        Product dissatisfaction
# 4   Competitor offered more data   Competitor offered more data
#
# [5 rows x 40 columns]

# %% [markdown]
# ## Processing Churn Reasons and Making Predictions for Target Customers

# %%
x_train_reason

le = LabelEncoder()
y_train_reason = le.fit_transform(y_train_reason)

# %%
x_train_reason
# Out:
#       Gender  Age  Married  Number of Dependents  City  Number of Referrals  \
# 2          1   37        0                     0   554                    0
# 4          0   19        0                     2   554                    0
# 5          0   31        0                     2   554                    0
# 13         1   38        0                     1   554                    0
# 18         0   21        1                     0   854                    6
# ...      ...  ...      ...                   ...   ...                  ...
# 7018       1   64        1                     2   695                    1
# 7021       1   44        0                     0   723                    0
# 7026       0   40        0                     0   905                    0
# 7032       1   79        0                     0   306                    0
# 7041       1   75        1                     0   316                    0
#
#       Offer  Online Security  Device Protection Plan  Premium Tech Support  \
# 2         1                1                       0                     0
# 4         1                0                       0                     0
# 5         1                0                       1                     0
# 13        1                0                       1                     0
# 18        1                0                       1                     1
# ...     ...              ...                     ...                   ...
# 7018      1                0                       0                     0
# 7021      3                0                       0                     1
# 7026      1                0                       0                     0
# 7032      1                0                       0                     0
# 7041      1                0                       0                     0
#
#       ...  Tenure In Years  Total Revenue      cltv  Cluster  \
# 2     ...             0.17         129.09  0.002610        0
# 4     ...             0.17         169.89  0.003660        0
# 5     ...             0.67         917.70  0.078054        0
# 13    ...             4.08        7208.47  2.917522        2
# 18    ...             0.83         622.45  0.062265        0
# ...   ...              ...            ...       ...      ...
# 7018  ...             0.08         108.33  0.000802        0
# 7021  ...             1.00         843.00  0.103337        0
# 7026  ...             0.75         780.63  0.042952        0
# 7032  ...             0.08          84.10  0.000860        0
# 7041  ...             0.33         369.04  0.014366        0
#
#       Streaming Services-1  Streaming Services-2  Charges-1  Charges-2  \
# 2                -1.333973             -0.157216  -1.569044  -0.617957
# 4                -1.333973             -0.157216  -1.333120  -0.933175
# 5                 2.227598              0.186057  -0.603732  -1.224686
# 13                2.227598              0.186057   2.625339   0.820637
# 18               -1.333973             -0.157216  -1.412004  -0.714972
# ...                    ...                   ...        ...        ...
# 7018             -1.333973             -0.157216  -0.741027   0.625236
# 7021             -0.325106              1.622951  -1.272123  -0.784960
# 7026             -1.333973             -0.157216  -0.737632   1.328836
# 7032             -1.333973             -0.157216  -1.299465  -1.040135
# 7041             -1.333973             -0.157216  -1.068568  -1.088837
#
#       Charges-3  Charges-4
# 2     -0.270518  -0.188623
# 4     -0.340048  -0.283804
# 5     -0.443543  -0.433743
# 13    -0.281941  -0.489975
# 18    -0.286838  -0.241256
# ...         ...        ...
# 7018  -0.197841   0.048530
# 7021  -0.306552  -0.275683
# 7026  -0.067987   0.177239
# 7032  -0.360949  -0.309537
# 7041  -0.352247   0.470398
#
# [1496 rows x 22 columns]

# %%
y_train_reason
# Out:
# array([ 3, 13, 13, ...,  4,  3,  3])

# %% [markdown]
# # Random Forest Model

# %%
TRF = RandomForestClassifier(random_state=10)

grid1 = GridSearchCV(estimator=TRF,
                    param_grid=param,
                    scoring="accuracy",
                    verbose=1, cv=3)

grid1.fit(x_train_reason,y_train_reason)
# Out:
# Fitting 3 folds for each of 64 candidates, totalling 192 fits
# GridSearchCV(cv=3, estimator=RandomForestClassifier(random_state=10),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [2, 4, 6, 8],
#                          'max_features': ['sqrt', 'log2'],
#                          'n_estimators': [10, 20, 50, 100]},
#              scoring='accuracy', verbose=1)

# %%
trf = grid1.best_estimator_

# %%
x_train_reason.columns
# Out:
# Index(['Gender', 'Age', 'Married', 'Number of Dependents', 'City',
#        'Number of Referrals', 'Offer', 'Online Security',
#        'Device Protection Plan', 'Premium Tech Support', 'Unlimited Data',
#        'Contract', 'Tenure In Years', 'Total Revenue', 'cltv', 'Cluster',
#        'Streaming Services-1', 'Streaming Services-2', 'Charges-1',
#        'Charges-2', 'Charges-3', 'Charges-4'],
#       dtype='object')

# %%
## getting records of customer that are high-valued and going to churn

x_test=x_test[(x_test['Cluster'] == 2) & (x_test['Churn'] == 1)]

# %%
x_test.drop("Churn",axis=1,inplace=True)
# Out:
# <ipython-input-102-01a3d2614561>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x_test.drop("Churn",axis=1,inplace=True)

# %%
reasons_ypred = trf.predict(x_test)

# %%
pd.Series(reasons_ypred).unique()
# Out:
# array([3, 2])

# %%
decoded_data = le.inverse_transform(reasons_ypred)
print("Decoded data:", decoded_data)
# Out:
# Decoded data: ['Competitor made better offer' 'Competitor had better devices'
#  'Competitor had better devices' 'Competitor had better devices'
#  'Competitor made better offer' 'Competitor had better devices'
#  'Competitor had better devices' 'Competitor made better offer'
#  'Competitor made better offer' 'Competitor had better devices'
#  'Competitor made better offer' 'Competitor had better devices'
#  'Competitor made better offer' 'Competitor made better offer'
#  'Competitor had better devices' 'Competitor had better devices'
#  'Competitor had better devices' 'Competitor had better devices'
#  'Competitor made better offer' 'Competitor had better devices'
#  'Competitor made better offer']

# %%
pd.Series(decoded_data).unique()
# Out:
# array(['Competitor made better offer', 'Competitor had better devices'],
#       dtype=object)

# %%
unique_values, counts = np.unique(decoded_data, return_counts=True)

for value, count in zip(unique_values, counts):
    print(f"Value: {value}, Count: {count}")
# Out:
# Value: Competitor had better devices, Count: 12
# Value: Competitor made better offer, Count: 9
